# %% [markdown]
# # Mount to google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Install required package

# %%
# !pip3 install efficient-apriori
# Out:
# Collecting efficient-apriori
#   Downloading https://files.pythonhosted.org/packages/5a/c6/ecdf3a32d23cada466634c649cf4f50fefe76f56eae53ecceff688b306be/efficient_apriori-1.1.1-py3-none-any.whl
# Installing collected packages: efficient-apriori
# Successfully installed efficient-apriori-1.1.1

# %% [markdown]
# # Get the file

# %%
root_dir = '/content/drive/My Drive/Data Mining/'
base_dir = root_dir + 'Data Mining/Project/'
file = base_dir + 'cleandata_sales.xlsx'

train_file = base_dir + 'Store Sales data/train.csv'
stores_file = base_dir + 'Store Sales data/stores.csv'
features_file = base_dir + 'Store Sales data/features.csv'
test_file = base_dir + 'Store Sales data/test.csv'

# %% [markdown]
# # Import

# %%
import numpy as np
import pandas as pd
from efficient_apriori import apriori 
import matplotlib.pyplot as plt

# %% [markdown]
# # Prepare the data

# %%
# read files
# bef_nov_dataframe = pd.read_excel(file, sheet_name = 'before2011nov')
# aft_nov_dataframe = pd.read_excel(file, sheet_name = 'after2011nov')
# aft_nov_noCPI_dataframe = pd.read_excel(file, sheet_name = 'after2011nov_noCPI')
# aft_nov__CPI_dataframe = pd.read_excel(file, sheet_name = 'after2011nov_CPI')

# read files
train_dataframe = pd.read_csv(train_file)
stores_dataframe = pd.read_csv(stores_file)
features_dataframe = pd.read_csv(features_file)
test_dataframe = pd.read_csv(test_file)
features_dataframe = features_dataframe.drop(columns='IsHoliday')

# left join other tables
train_dataframe = pd.merge(train_dataframe, stores_dataframe, how='left', left_on='Store', right_on='Store')
train_dataframe = pd.merge(train_dataframe, features_dataframe,  how='left', left_on=['Store','Date'], right_on = ['Store','Date']) 

# # Drop MarkDown 1-5
# train_dataframe = train_dataframe.drop(columns=['MarkDown1', 'MarkDown2', 'MarkDown3', 'MarkDown4','MarkDown5'])  

# file 0
train_dataframe = train_dataframe.fillna(0)

# %%
def splitByNumberClassesAndSetToMeanRange(dataframe, attribute, numberClasses):
  min = dataframe[attribute].min() 
  max = dataframe[attribute].max() 
  range_diff = (max - min) / numberClasses
  for i in range(numberClasses):
    lower_bound = min + range_diff * i
    higher_bound = min + range_diff * (i + 1)
    mean = round(min + (range_diff) * i + range_diff / 2, 2)
    dataframe.loc[(dataframe[attribute] >= lower_bound) & (dataframe[attribute] < higher_bound), attribute] = mean


def classifyNumericalAttribute(dataframe): 
  #classify numerical attribute
  #input: dataframe, attribute, number of classes
  splitByNumberClassesAndSetToMeanRange(dataframe, 'Temperature', 10)
  splitByNumberClassesAndSetToMeanRange(dataframe, 'Fuel_Price', 10)
  splitByNumberClassesAndSetToMeanRange(dataframe, 'MarkDown1', 1000)
  splitByNumberClassesAndSetToMeanRange(dataframe, 'MarkDown2', 1000)
  splitByNumberClassesAndSetToMeanRange(dataframe, 'MarkDown3', 1000)
  splitByNumberClassesAndSetToMeanRange(dataframe, 'MarkDown4', 1000)
  splitByNumberClassesAndSetToMeanRange(dataframe, 'MarkDown5', 1000)
  splitByNumberClassesAndSetToMeanRange(dataframe, 'CPI', 10)
  splitByNumberClassesAndSetToMeanRange(dataframe, 'Unemployment', 10)
  # splitByNumberClassesAndSetToMeanRange(dataframe, 'store size', 10)
  # splitByNumberClassesAndSetToMeanRange(dataframe, 'weekly sales', 10)
  splitByNumberClassesAndSetToMeanRange(dataframe, 'Size', 10)
  splitByNumberClassesAndSetToMeanRange(dataframe, 'Weekly_Sales', 10)

  #convert type of attribute to string, the apriori method only allow string and bool
  attributeList = dataframe.columns
  total_rows = dataframe.shape[0]

  for i in attributeList:
    dataframe[i]= dataframe[i].astype(str)
    for j in range(total_rows):
      temp = dataframe.loc[j, i]
      dataframe.loc[j, i] = i + ' ' + temp


def splitByFrequency(dataframe, attribute, num):
  dataframe['new'] = attribute + ': '
  dataframe['cuts'] = (pd.qcut(dataframe[attribute].tolist(), num, duplicates='drop').codes).astype(str)
  dataframe[attribute] = dataframe['new'] + dataframe['cuts']
  dataframe.drop(columns=['new', 'cuts'])
  return dataframe

def classifyNumericalAttributeByFrequency(dataframe, dictionary):
  attributeList = dataframe.columns
  i = 0
  for attri in attributeList:
    if attri == 'Store' or attri == 'Dept' or attri == 'IsHoliday' or attri == 'Type' or attri == 'Date':
      dataframe['new'] = attri + ': '
      dataframe['cuts'] = dataframe[attri].astype(str)
      dataframe[attri] = dataframe['new'] + dataframe['cuts']
      dataframe = dataframe.drop(columns=['new', 'cuts'])
    else:
      dataframe  = splitByFrequency(dataframe, attri, dictionary[attri])
      dataframe = dataframe.drop(columns=['new', 'cuts'])
    i += 1
    # dataframe = dataframe.drop(columns=['new', 'cuts'])
  return dataframe

# %% [markdown]
# # Implement Apriori

# %%
# split by equally value
def apriori_algorithm(dataframe, support_rate, confidence_rate):
  classifyNumericalAttribute(dataframe)
  # Convert dataframe to list of tuples in order to run the apriori method.
  transactions_from_df = [tuple(row) for row in dataframe.values.tolist()] 
  itemsets, rules = apriori(transactions_from_df, min_support=support_rate, min_confidence=confidence_rate)
  return itemsets, rules

# %%
# split by equally quantity
def apriori_algorithm_quantity(dataframe, support_rate, confidence_rate):
  numDict ={}
  numDict['Temperature'] = 10
  numDict['Fuel_Price'] = 10
  numDict['MarkDown1'] = 10
  numDict['MarkDown2'] = 10
  numDict['MarkDown3'] = 10
  numDict['MarkDown4'] = 10
  numDict['MarkDown5'] = 10
  numDict['CPI'] = 10
  numDict['Unemployment'] = 10
  numDict['Size'] = 10
  numDict['Weekly_Sales'] = 10

  df = classifyNumericalAttributeByFrequency(train_dataframe, numDict)
  # Convert dataframe to list of tuples in order to run the apriori method.
  transactions_from_df = [tuple(row) for row in df.values.tolist()] 
  itemsets, rules = apriori(transactions_from_df, min_support=support_rate, min_confidence=confidence_rate)
  return itemsets, rules

# %% [markdown]
# # Run Apriori

# %%
# Please use a copied framework as the parameter for the apriori_algorithm
# bef_nov_dataframe_copy = bef_nov_dataframe.copy()
# aft_nov_dataframe_copy = aft_nov_dataframe.copy()
# aft_nov_noCPI_dataframe_copy = aft_nov_noCPI_dataframe.copy()
# aft_nov__CPI_dataframe_copy = aft_nov__CPI_dataframe.copy()

train_dataframe_copy = train_dataframe.copy()

#please put the copied framework in the first parameter.
itemsets, rules = apriori_algorithm(train_dataframe_copy, 0.5, 0.3)

# %%
train_dataframe_copy = train_dataframe.copy()

itemsets_q, rules_q = apriori_algorithm_quantity(train_dataframe_copy, 0.01, 0.1)

# %% [markdown]
# # Result

# %%
rules_rhs = filter(lambda rule: len(rule.rhs) == 1 and rule.rhs[0].find('Weekly_Sales') != -1, rules_q)
for rule in sorted(rules_rhs, key=lambda rule: rule.lift, reverse=True):
  print(rule)
# Out:
# {Dept: 54} -> {Weekly_Sales: 0} (conf: 0.916, supp: 0.010, lift: 9.163, conv: 10.753)
# {Dept: 38, IsHoliday: False} -> {Weekly_Sales: 9} (conf: 0.773, supp: 0.011, lift: 7.728, conv: 3.961)
# {Dept: 38} -> {Weekly_Sales: 9} (conf: 0.768, supp: 0.012, lift: 7.681, conv: 3.882)
# {Dept: 95, IsHoliday: False} -> {Weekly_Sales: 9} (conf: 0.718, supp: 0.010, lift: 7.181, conv: 3.193)
# {Dept: 95} -> {Weekly_Sales: 9} (conf: 0.714, supp: 0.011, lift: 7.144, conv: 3.151)
# {Dept: 92} -> {Weekly_Sales: 9} (conf: 0.687, supp: 0.010, lift: 6.866, conv: 2.871)
# {Size: 0, Type: A} -> {Weekly_Sales: 0} (conf: 0.354, supp: 0.011, lift: 3.538, conv: 1.393)
# {CPI: 1, Size: 0} -> {Weekly_Sales: 0} (conf: 0.353, supp: 0.010, lift: 3.531, conv: 1.391)
# {IsHoliday: False, Size: 1, Type: C} -> {Weekly_Sales: 0} (conf: 0.326, supp: 0.010, lift: 3.264, conv: 1.336)
# {Size: 1, Type: C} -> {Weekly_Sales: 0} (conf: 0.326, supp: 0.011, lift: 3.257, conv: 1.335)
# {IsHoliday: False, Type: C} -> {Weekly_Sales: 0} (conf: 0.320, supp: 0.030, lift: 3.203, conv: 1.324)
# {Type: C} -> {Weekly_Sales: 0} (conf: 0.320, supp: 0.032, lift: 3.196, conv: 1.323)
# {IsHoliday: False, Size: 0, Type: C} -> {Weekly_Sales: 0} (conf: 0.317, supp: 0.020, lift: 3.173, conv: 1.318)
# {Size: 0, Type: C} -> {Weekly_Sales: 0} (conf: 0.317, supp: 0.022, lift: 3.166, conv: 1.317)
# {IsHoliday: False, Size: 0} -> {Weekly_Sales: 0} (conf: 0.263, supp: 0.034, lift: 2.631, conv: 1.221)
# {Size: 0} -> {Weekly_Sales: 0} (conf: 0.262, supp: 0.037, lift: 2.624, conv: 1.220)
# {IsHoliday: False, Size: 0, Type: C} -> {Weekly_Sales: 1} (conf: 0.210, supp: 0.013, lift: 2.100, conv: 1.139)
# {Size: 0, Type: C} -> {Weekly_Sales: 1} (conf: 0.210, supp: 0.014, lift: 2.098, conv: 1.139)
# {Size: 1} -> {Weekly_Sales: 0} (conf: 0.203, supp: 0.016, lift: 2.031, conv: 1.129)
# {IsHoliday: False, Size: 1} -> {Weekly_Sales: 0} (conf: 0.203, supp: 0.015, lift: 2.030, conv: 1.129)
# {Size: 0} -> {Weekly_Sales: 1} (conf: 0.198, supp: 0.028, lift: 1.979, conv: 1.122)
# {IsHoliday: False, Size: 0} -> {Weekly_Sales: 1} (conf: 0.198, supp: 0.026, lift: 1.979, conv: 1.122)
# {IsHoliday: False, Type: C} -> {Weekly_Sales: 1} (conf: 0.197, supp: 0.019, lift: 1.974, conv: 1.121)
# {Type: C} -> {Weekly_Sales: 1} (conf: 0.197, supp: 0.020, lift: 1.973, conv: 1.121)
# {Size: 7} -> {Weekly_Sales: 9} (conf: 0.180, supp: 0.017, lift: 1.798, conv: 1.097)
# {Size: 7, Type: A} -> {Weekly_Sales: 9} (conf: 0.180, supp: 0.017, lift: 1.798, conv: 1.097)
# {IsHoliday: False, Size: 7} -> {Weekly_Sales: 9} (conf: 0.179, supp: 0.016, lift: 1.793, conv: 1.097)
# {IsHoliday: False, Size: 7, Type: A} -> {Weekly_Sales: 9} (conf: 0.179, supp: 0.016, lift: 1.793, conv: 1.097)
# {Size: 9} -> {Weekly_Sales: 9} (conf: 0.173, supp: 0.017, lift: 1.727, conv: 1.088)
# {Size: 9, Type: A} -> {Weekly_Sales: 9} (conf: 0.173, supp: 0.017, lift: 1.727, conv: 1.088)
# {IsHoliday: False, Size: 9} -> {Weekly_Sales: 9} (conf: 0.172, supp: 0.016, lift: 1.722, conv: 1.087)
# {IsHoliday: False, Size: 9, Type: A} -> {Weekly_Sales: 9} (conf: 0.172, supp: 0.016, lift: 1.722, conv: 1.087)
# {IsHoliday: False, Size: 1} -> {Weekly_Sales: 1} (conf: 0.152, supp: 0.011, lift: 1.517, conv: 1.061)
# {Size: 1} -> {Weekly_Sales: 1} (conf: 0.151, supp: 0.012, lift: 1.510, conv: 1.060)
# {Temperature: 9} -> {Weekly_Sales: 0} (conf: 0.148, supp: 0.015, lift: 1.483, conv: 1.057)
# {IsHoliday: False, Temperature: 9} -> {Weekly_Sales: 0} (conf: 0.148, supp: 0.014, lift: 1.478, conv: 1.056)
# {Size: 8} -> {Weekly_Sales: 9} (conf: 0.147, supp: 0.014, lift: 1.474, conv: 1.056)
# {Size: 8, Type: A} -> {Weekly_Sales: 9} (conf: 0.147, supp: 0.014, lift: 1.474, conv: 1.056)
# {IsHoliday: False, Size: 8} -> {Weekly_Sales: 9} (conf: 0.147, supp: 0.013, lift: 1.469, conv: 1.055)
# {IsHoliday: False, Size: 8, Type: A} -> {Weekly_Sales: 9} (conf: 0.147, supp: 0.013, lift: 1.469, conv: 1.055)
# {CPI: 1, IsHoliday: False} -> {Weekly_Sales: 0} (conf: 0.145, supp: 0.014, lift: 1.449, conv: 1.053)
# {CPI: 1} -> {Weekly_Sales: 0} (conf: 0.144, supp: 0.015, lift: 1.443, conv: 1.052)
# {IsHoliday: False, Unemployment: 9} -> {Weekly_Sales: 0} (conf: 0.141, supp: 0.013, lift: 1.414, conv: 1.048)
# {Size: 6} -> {Weekly_Sales: 9} (conf: 0.141, supp: 0.013, lift: 1.413, conv: 1.048)
# {Size: 6, Type: A} -> {Weekly_Sales: 9} (conf: 0.141, supp: 0.013, lift: 1.413, conv: 1.048)
# {Unemployment: 9} -> {Weekly_Sales: 0} (conf: 0.141, supp: 0.014, lift: 1.410, conv: 1.048)
# {IsHoliday: False, Size: 6} -> {Weekly_Sales: 9} (conf: 0.141, supp: 0.013, lift: 1.410, conv: 1.048)
# {IsHoliday: False, Size: 6, Type: A} -> {Weekly_Sales: 9} (conf: 0.141, supp: 0.013, lift: 1.410, conv: 1.048)
# {Size: 9} -> {Weekly_Sales: 8} (conf: 0.141, supp: 0.014, lift: 1.408, conv: 1.047)
# {Size: 9, Type: A} -> {Weekly_Sales: 8} (conf: 0.141, supp: 0.014, lift: 1.408, conv: 1.047)
# {IsHoliday: False, Size: 9} -> {Weekly_Sales: 8} (conf: 0.140, supp: 0.013, lift: 1.404, conv: 1.047)
# {IsHoliday: False, Size: 9, Type: A} -> {Weekly_Sales: 8} (conf: 0.140, supp: 0.013, lift: 1.404, conv: 1.047)
# {Type: A} -> {Weekly_Sales: 9} (conf: 0.138, supp: 0.071, lift: 1.381, conv: 1.044)
# {IsHoliday: False, Type: A} -> {Weekly_Sales: 9} (conf: 0.138, supp: 0.065, lift: 1.377, conv: 1.044)
# {IsHoliday: False, Size: 4} -> {Weekly_Sales: 3} (conf: 0.136, supp: 0.015, lift: 1.360, conv: 1.042)
# {IsHoliday: False, Size: 4, Type: B} -> {Weekly_Sales: 3} (conf: 0.136, supp: 0.015, lift: 1.360, conv: 1.042)
# {IsHoliday: False, Unemployment: 1} -> {Weekly_Sales: 2} (conf: 0.136, supp: 0.013, lift: 1.358, conv: 1.041)
# {Unemployment: 1} -> {Weekly_Sales: 2} (conf: 0.135, supp: 0.014, lift: 1.353, conv: 1.041)
# {Size: 4} -> {Weekly_Sales: 3} (conf: 0.135, supp: 0.015, lift: 1.347, conv: 1.040)
# {Size: 4, Type: B} -> {Weekly_Sales: 3} (conf: 0.135, supp: 0.015, lift: 1.347, conv: 1.040)
# {Size: 7} -> {Weekly_Sales: 8} (conf: 0.131, supp: 0.013, lift: 1.314, conv: 1.036)
# {Size: 7, Type: A} -> {Weekly_Sales: 8} (conf: 0.131, supp: 0.013, lift: 1.314, conv: 1.036)
# {CPI: 0, IsHoliday: False} -> {Weekly_Sales: 0} (conf: 0.131, supp: 0.012, lift: 1.313, conv: 1.036)
# {CPI: 0} -> {Weekly_Sales: 0} (conf: 0.131, supp: 0.013, lift: 1.313, conv: 1.036)
# {IsHoliday: False, Size: 7} -> {Weekly_Sales: 8} (conf: 0.131, supp: 0.012, lift: 1.310, conv: 1.036)
# {IsHoliday: False, Size: 7, Type: A} -> {Weekly_Sales: 8} (conf: 0.131, supp: 0.012, lift: 1.310, conv: 1.036)
# {IsHoliday: False, Size: 8} -> {Weekly_Sales: 8} (conf: 0.127, supp: 0.011, lift: 1.267, conv: 1.031)
# {IsHoliday: False, Size: 8, Type: A} -> {Weekly_Sales: 8} (conf: 0.127, supp: 0.011, lift: 1.267, conv: 1.031)
# {Size: 8} -> {Weekly_Sales: 8} (conf: 0.127, supp: 0.012, lift: 1.265, conv: 1.030)
# {Size: 8, Type: A} -> {Weekly_Sales: 8} (conf: 0.127, supp: 0.012, lift: 1.265, conv: 1.030)
# {IsHoliday: False, Size: 5} -> {Weekly_Sales: 2} (conf: 0.126, supp: 0.011, lift: 1.264, conv: 1.030)
# {IsHoliday: False, Size: 5, Type: A} -> {Weekly_Sales: 2} (conf: 0.126, supp: 0.011, lift: 1.264, conv: 1.030)
# {Size: 5} -> {Weekly_Sales: 2} (conf: 0.126, supp: 0.012, lift: 1.263, conv: 1.030)
# {Size: 5, Type: A} -> {Weekly_Sales: 2} (conf: 0.126, supp: 0.012, lift: 1.263, conv: 1.030)
# {Unemployment: 0} -> {Weekly_Sales: 8} (conf: 0.125, supp: 0.013, lift: 1.251, conv: 1.029)
# {IsHoliday: False, Unemployment: 0} -> {Weekly_Sales: 8} (conf: 0.125, supp: 0.012, lift: 1.248, conv: 1.028)
# {Type: B} -> {Weekly_Sales: 2} (conf: 0.125, supp: 0.048, lift: 1.248, conv: 1.028)
# {IsHoliday: False, Type: B} -> {Weekly_Sales: 2} (conf: 0.125, supp: 0.045, lift: 1.246, conv: 1.028)
# {Unemployment: 9} -> {Weekly_Sales: 1} (conf: 0.124, supp: 0.012, lift: 1.238, conv: 1.027)
# {IsHoliday: False, Unemployment: 9} -> {Weekly_Sales: 1} (conf: 0.124, supp: 0.011, lift: 1.237, conv: 1.027)
# {Unemployment: 8} -> {Weekly_Sales: 0} (conf: 0.124, supp: 0.012, lift: 1.236, conv: 1.027)
# {IsHoliday: False, Unemployment: 8} -> {Weekly_Sales: 0} (conf: 0.123, supp: 0.011, lift: 1.234, conv: 1.027)
# {CPI: 5, IsHoliday: False} -> {Weekly_Sales: 3} (conf: 0.123, supp: 0.011, lift: 1.228, conv: 1.026)
# {Type: A} -> {Weekly_Sales: 8} (conf: 0.123, supp: 0.063, lift: 1.227, conv: 1.026)
# {CPI: 5} -> {Weekly_Sales: 2} (conf: 0.123, supp: 0.012, lift: 1.227, conv: 1.026)
# {IsHoliday: False, Size: 6} -> {Weekly_Sales: 7} (conf: 0.123, supp: 0.011, lift: 1.226, conv: 1.026)
# {IsHoliday: False, Size: 6, Type: A} -> {Weekly_Sales: 7} (conf: 0.123, supp: 0.011, lift: 1.226, conv: 1.026)
# {Size: 6} -> {Weekly_Sales: 7} (conf: 0.123, supp: 0.012, lift: 1.226, conv: 1.026)
# {Size: 6, Type: A} -> {Weekly_Sales: 7} (conf: 0.123, supp: 0.012, lift: 1.226, conv: 1.026)
# {IsHoliday: False, Type: A} -> {Weekly_Sales: 8} (conf: 0.123, supp: 0.058, lift: 1.225, conv: 1.026)
# {IsHoliday: False, Type: B} -> {Weekly_Sales: 3} (conf: 0.122, supp: 0.044, lift: 1.224, conv: 1.026)
# {CPI: 5, IsHoliday: False} -> {Weekly_Sales: 2} (conf: 0.122, supp: 0.011, lift: 1.224, conv: 1.025)
# {CPI: 5} -> {Weekly_Sales: 3} (conf: 0.122, supp: 0.012, lift: 1.223, conv: 1.025)
# {Type: B} -> {Weekly_Sales: 3} (conf: 0.122, supp: 0.047, lift: 1.217, conv: 1.025)
# {Size: 4} -> {Weekly_Sales: 2} (conf: 0.121, supp: 0.014, lift: 1.214, conv: 1.024)
# {Size: 4, Type: B} -> {Weekly_Sales: 2} (conf: 0.121, supp: 0.014, lift: 1.214, conv: 1.024)
# {IsHoliday: False, Size: 4} -> {Weekly_Sales: 2} (conf: 0.121, supp: 0.013, lift: 1.208, conv: 1.024)
# {IsHoliday: False, Size: 4, Type: B} -> {Weekly_Sales: 2} (conf: 0.121, supp: 0.013, lift: 1.208, conv: 1.024)
# {Temperature: 0} -> {Weekly_Sales: 2} (conf: 0.120, supp: 0.012, lift: 1.203, conv: 1.023)
# {Temperature: 8} -> {Weekly_Sales: 0} (conf: 0.120, supp: 0.012, lift: 1.198, conv: 1.022)
# {Unemployment: 1} -> {Weekly_Sales: 3} (conf: 0.120, supp: 0.012, lift: 1.197, conv: 1.022)
# {IsHoliday: False, Temperature: 8} -> {Weekly_Sales: 0} (conf: 0.120, supp: 0.011, lift: 1.196, conv: 1.022)
# {Size: 8} -> {Weekly_Sales: 7} (conf: 0.120, supp: 0.012, lift: 1.196, conv: 1.022)
# {Size: 8, Type: A} -> {Weekly_Sales: 7} (conf: 0.120, supp: 0.012, lift: 1.196, conv: 1.022)
# {IsHoliday: False, Temperature: 9} -> {Weekly_Sales: 1} (conf: 0.119, supp: 0.011, lift: 1.195, conv: 1.022)
# {Temperature: 9} -> {Weekly_Sales: 1} (conf: 0.119, supp: 0.012, lift: 1.194, conv: 1.022)
# {IsHoliday: False, Unemployment: 1} -> {Weekly_Sales: 3} (conf: 0.119, supp: 0.011, lift: 1.194, conv: 1.022)
# {IsHoliday: False, Size: 7} -> {Weekly_Sales: 7} (conf: 0.119, supp: 0.011, lift: 1.194, conv: 1.022)
# {IsHoliday: False, Size: 7, Type: A} -> {Weekly_Sales: 7} (conf: 0.119, supp: 0.011, lift: 1.194, conv: 1.022)
# {Size: 7} -> {Weekly_Sales: 7} (conf: 0.119, supp: 0.012, lift: 1.193, conv: 1.022)
# {Size: 7, Type: A} -> {Weekly_Sales: 7} (conf: 0.119, supp: 0.012, lift: 1.193, conv: 1.022)
# {IsHoliday: False, Size: 9} -> {Weekly_Sales: 5} (conf: 0.119, supp: 0.011, lift: 1.188, conv: 1.021)
# {IsHoliday: False, Size: 9, Type: A} -> {Weekly_Sales: 5} (conf: 0.119, supp: 0.011, lift: 1.188, conv: 1.021)
# {CPI: 1} -> {Weekly_Sales: 9} (conf: 0.118, supp: 0.012, lift: 1.183, conv: 1.021)
# {IsHoliday: False, Size: 8} -> {Weekly_Sales: 7} (conf: 0.118, supp: 0.011, lift: 1.182, conv: 1.021)
# {IsHoliday: False, Size: 8, Type: A} -> {Weekly_Sales: 7} (conf: 0.118, supp: 0.011, lift: 1.182, conv: 1.021)
# {Size: 3} -> {Weekly_Sales: 8} (conf: 0.118, supp: 0.011, lift: 1.178, conv: 1.020)
# {Size: 3, Type: B} -> {Weekly_Sales: 8} (conf: 0.118, supp: 0.011, lift: 1.178, conv: 1.020)
# {CPI: 1, IsHoliday: False} -> {Weekly_Sales: 9} (conf: 0.118, supp: 0.011, lift: 1.177, conv: 1.020)
# {CPI: 8} -> {Weekly_Sales: 2} (conf: 0.118, supp: 0.012, lift: 1.176, conv: 1.020)
# {CPI: 8, IsHoliday: False} -> {Weekly_Sales: 2} (conf: 0.118, supp: 0.011, lift: 1.176, conv: 1.020)
# {Size: 9} -> {Weekly_Sales: 5} (conf: 0.118, supp: 0.011, lift: 1.175, conv: 1.020)
# {Size: 9, Type: A} -> {Weekly_Sales: 5} (conf: 0.118, supp: 0.011, lift: 1.175, conv: 1.020)
# {IsHoliday: False, Size: 3} -> {Weekly_Sales: 8} (conf: 0.117, supp: 0.010, lift: 1.175, conv: 1.020)
# {IsHoliday: False, Size: 3, Type: B} -> {Weekly_Sales: 8} (conf: 0.117, supp: 0.010, lift: 1.175, conv: 1.020)
# {IsHoliday: False, Unemployment: 1} -> {Weekly_Sales: 1} (conf: 0.117, supp: 0.011, lift: 1.174, conv: 1.020)
# {Unemployment: 1} -> {Weekly_Sales: 1} (conf: 0.117, supp: 0.012, lift: 1.173, conv: 1.020)
# {Unemployment: 7} -> {Weekly_Sales: 6} (conf: 0.117, supp: 0.012, lift: 1.172, conv: 1.020)
# {IsHoliday: False, Size: 5} -> {Weekly_Sales: 8} (conf: 0.117, supp: 0.010, lift: 1.167, conv: 1.019)
# {IsHoliday: False, Size: 5, Type: A} -> {Weekly_Sales: 8} (conf: 0.117, supp: 0.010, lift: 1.167, conv: 1.019)
# {IsHoliday: False, Unemployment: 7} -> {Weekly_Sales: 6} (conf: 0.117, supp: 0.011, lift: 1.166, conv: 1.019)
# {Size: 5} -> {Weekly_Sales: 8} (conf: 0.116, supp: 0.011, lift: 1.163, conv: 1.018)
# {Size: 5, Type: A} -> {Weekly_Sales: 8} (conf: 0.116, supp: 0.011, lift: 1.163, conv: 1.018)
# {Unemployment: 3} -> {Weekly_Sales: 9} (conf: 0.116, supp: 0.012, lift: 1.159, conv: 1.018)
# {CPI: 4} -> {Weekly_Sales: 8} (conf: 0.116, supp: 0.012, lift: 1.159, conv: 1.018)
# {IsHoliday: False, Unemployment: 3} -> {Weekly_Sales: 9} (conf: 0.116, supp: 0.011, lift: 1.159, conv: 1.018)
# {Unemployment: 5} -> {Weekly_Sales: 9} (conf: 0.116, supp: 0.012, lift: 1.156, conv: 1.018)
# {CPI: 4, IsHoliday: False} -> {Weekly_Sales: 8} (conf: 0.116, supp: 0.011, lift: 1.155, conv: 1.018)
# {Size: 3} -> {Weekly_Sales: 6} (conf: 0.115, supp: 0.011, lift: 1.154, conv: 1.017)
# {Size: 3, Type: B} -> {Weekly_Sales: 6} (conf: 0.115, supp: 0.011, lift: 1.154, conv: 1.017)
# {Temperature: 0} -> {Weekly_Sales: 3} (conf: 0.115, supp: 0.012, lift: 1.153, conv: 1.017)
# {CPI: 3} -> {Weekly_Sales: 7} (conf: 0.115, supp: 0.012, lift: 1.151, conv: 1.017)
# {IsHoliday: False, Unemployment: 5} -> {Weekly_Sales: 9} (conf: 0.115, supp: 0.011, lift: 1.151, conv: 1.017)
# {CPI: 4} -> {Weekly_Sales: 7} (conf: 0.115, supp: 0.011, lift: 1.149, conv: 1.017)
# {Size: 6} -> {Weekly_Sales: 8} (conf: 0.115, supp: 0.011, lift: 1.148, conv: 1.017)
# {Size: 6, Type: A} -> {Weekly_Sales: 8} (conf: 0.115, supp: 0.011, lift: 1.148, conv: 1.017)
# {IsHoliday: False, Size: 4} -> {Weekly_Sales: 5} (conf: 0.114, supp: 0.012, lift: 1.144, conv: 1.016)
# {IsHoliday: False, Size: 4, Type: B} -> {Weekly_Sales: 5} (conf: 0.114, supp: 0.012, lift: 1.144, conv: 1.016)
# {Size: 4} -> {Weekly_Sales: 5} (conf: 0.114, supp: 0.013, lift: 1.144, conv: 1.016)
# {Size: 4, Type: B} -> {Weekly_Sales: 5} (conf: 0.114, supp: 0.013, lift: 1.144, conv: 1.016)
# {IsHoliday: False, Size: 5} -> {Weekly_Sales: 3} (conf: 0.114, supp: 0.010, lift: 1.144, conv: 1.016)
# {IsHoliday: False, Size: 5, Type: A} -> {Weekly_Sales: 3} (conf: 0.114, supp: 0.010, lift: 1.144, conv: 1.016)
# {CPI: 4, IsHoliday: False} -> {Weekly_Sales: 7} (conf: 0.114, supp: 0.011, lift: 1.143, conv: 1.016)
# {IsHoliday: False, Size: 6} -> {Weekly_Sales: 8} (conf: 0.114, supp: 0.010, lift: 1.143, conv: 1.016)
# {IsHoliday: False, Size: 6, Type: A} -> {Weekly_Sales: 8} (conf: 0.114, supp: 0.010, lift: 1.143, conv: 1.016)
# {CPI: 3, IsHoliday: False} -> {Weekly_Sales: 7} (conf: 0.114, supp: 0.010, lift: 1.142, conv: 1.016)
# {Size: 5} -> {Weekly_Sales: 3} (conf: 0.114, supp: 0.011, lift: 1.142, conv: 1.016)
# {Size: 5, Type: A} -> {Weekly_Sales: 3} (conf: 0.114, supp: 0.011, lift: 1.142, conv: 1.016)
# {Size: 3} -> {Weekly_Sales: 7} (conf: 0.114, supp: 0.011, lift: 1.141, conv: 1.016)
# {Size: 3, Type: B} -> {Weekly_Sales: 7} (conf: 0.114, supp: 0.011, lift: 1.141, conv: 1.016)
# {Size: 2} -> {Weekly_Sales: 5} (conf: 0.114, supp: 0.010, lift: 1.139, conv: 1.016)
# {Size: 2, Type: B} -> {Weekly_Sales: 5} (conf: 0.114, supp: 0.010, lift: 1.139, conv: 1.016)
# {IsHoliday: False, Temperature: 1} -> {Weekly_Sales: 3} (conf: 0.114, supp: 0.010, lift: 1.138, conv: 1.016)
# {IsHoliday: False, Temperature: 1} -> {Weekly_Sales: 2} (conf: 0.114, supp: 0.010, lift: 1.138, conv: 1.016)
# {Temperature: 1} -> {Weekly_Sales: 2} (conf: 0.114, supp: 0.011, lift: 1.136, conv: 1.015)
# {CPI: 6, IsHoliday: False} -> {Weekly_Sales: 0} (conf: 0.113, supp: 0.011, lift: 1.132, conv: 1.015)
# {CPI: 6} -> {Weekly_Sales: 0} (conf: 0.113, supp: 0.011, lift: 1.131, conv: 1.015)
# {CPI: 0} -> {Weekly_Sales: 9} (conf: 0.113, supp: 0.011, lift: 1.127, conv: 1.014)
# {CPI: 0, IsHoliday: False} -> {Weekly_Sales: 9} (conf: 0.113, supp: 0.010, lift: 1.125, conv: 1.014)
# {Size: 9} -> {Weekly_Sales: 7} (conf: 0.112, supp: 0.011, lift: 1.125, conv: 1.014)
# {Size: 9, Type: A} -> {Weekly_Sales: 7} (conf: 0.112, supp: 0.011, lift: 1.125, conv: 1.014)
# {Temperature: 1} -> {Weekly_Sales: 3} (conf: 0.112, supp: 0.011, lift: 1.124, conv: 1.014)
# {Size: 2} -> {Weekly_Sales: 4} (conf: 0.112, supp: 0.010, lift: 1.124, conv: 1.014)
# {Size: 2, Type: B} -> {Weekly_Sales: 4} (conf: 0.112, supp: 0.010, lift: 1.124, conv: 1.014)
# {Type: A} -> {Weekly_Sales: 7} (conf: 0.112, supp: 0.057, lift: 1.123, conv: 1.014)
# {CPI: 9, IsHoliday: False} -> {Weekly_Sales: 1} (conf: 0.112, supp: 0.011, lift: 1.123, conv: 1.014)
# {CPI: 1} -> {Weekly_Sales: 1} (conf: 0.112, supp: 0.011, lift: 1.121, conv: 1.014)
# {CPI: 9} -> {Weekly_Sales: 1} (conf: 0.112, supp: 0.011, lift: 1.121, conv: 1.014)
# {CPI: 1, IsHoliday: False} -> {Weekly_Sales: 1} (conf: 0.112, supp: 0.011, lift: 1.120, conv: 1.014)
# {CPI: 0, IsHoliday: False} -> {Weekly_Sales: 1} (conf: 0.112, supp: 0.010, lift: 1.119, conv: 1.013)
# {Type: B} -> {Weekly_Sales: 1} (conf: 0.112, supp: 0.043, lift: 1.119, conv: 1.013)
# {IsHoliday: False, Type: B} -> {Weekly_Sales: 1} (conf: 0.112, supp: 0.040, lift: 1.118, conv: 1.013)
# {IsHoliday: False, Type: A} -> {Weekly_Sales: 7} (conf: 0.112, supp: 0.053, lift: 1.118, conv: 1.013)
# {Size: 2} -> {Weekly_Sales: 3} (conf: 0.112, supp: 0.010, lift: 1.117, conv: 1.013)
# {Size: 2, Type: B} -> {Weekly_Sales: 3} (conf: 0.112, supp: 0.010, lift: 1.117, conv: 1.013)
# {CPI: 0} -> {Weekly_Sales: 1} (conf: 0.112, supp: 0.011, lift: 1.116, conv: 1.013)
# {IsHoliday: False, Size: 9} -> {Weekly_Sales: 7} (conf: 0.111, supp: 0.010, lift: 1.115, conv: 1.013)
# {IsHoliday: False, Size: 9, Type: A} -> {Weekly_Sales: 7} (conf: 0.111, supp: 0.010, lift: 1.115, conv: 1.013)
# {CPI: 6} -> {Weekly_Sales: 1} (conf: 0.111, supp: 0.011, lift: 1.115, conv: 1.013)
# {CPI: 3, IsHoliday: False} -> {Weekly_Sales: 3} (conf: 0.111, supp: 0.010, lift: 1.114, conv: 1.013)
# {CPI: 6, IsHoliday: False} -> {Weekly_Sales: 1} (conf: 0.111, supp: 0.010, lift: 1.112, conv: 1.013)
# {IsHoliday: False, Size: 9} -> {Weekly_Sales: 6} (conf: 0.111, supp: 0.010, lift: 1.111, conv: 1.012)
# {IsHoliday: False, Size: 9, Type: A} -> {Weekly_Sales: 6} (conf: 0.111, supp: 0.010, lift: 1.111, conv: 1.012)
# {Size: 2} -> {Weekly_Sales: 6} (conf: 0.111, supp: 0.010, lift: 1.110, conv: 1.012)
# {Size: 2, Type: B} -> {Weekly_Sales: 6} (conf: 0.111, supp: 0.010, lift: 1.110, conv: 1.012)
# {Size: 9} -> {Weekly_Sales: 6} (conf: 0.111, supp: 0.011, lift: 1.108, conv: 1.012)
# {Size: 9, Type: A} -> {Weekly_Sales: 6} (conf: 0.111, supp: 0.011, lift: 1.108, conv: 1.012)
# {Fuel_Price: 3} -> {Weekly_Sales: 9} (conf: 0.111, supp: 0.011, lift: 1.107, conv: 1.012)
# {CPI: 3} -> {Weekly_Sales: 3} (conf: 0.111, supp: 0.011, lift: 1.107, conv: 1.012)
# {IsHoliday: False, Unemployment: 1} -> {Weekly_Sales: 4} (conf: 0.111, supp: 0.010, lift: 1.105, conv: 1.012)
# {Unemployment: 6} -> {Weekly_Sales: 7} (conf: 0.110, supp: 0.011, lift: 1.104, conv: 1.012)
# {Size: 8} -> {Weekly_Sales: 4} (conf: 0.110, supp: 0.011, lift: 1.104, conv: 1.012)
# {Size: 8, Type: A} -> {Weekly_Sales: 4} (conf: 0.110, supp: 0.011, lift: 1.104, conv: 1.012)
# {IsHoliday: False, Unemployment: 6} -> {Weekly_Sales: 7} (conf: 0.110, supp: 0.010, lift: 1.103, conv: 1.012)
# {CPI: 3} -> {Weekly_Sales: 8} (conf: 0.110, supp: 0.011, lift: 1.102, conv: 1.012)
# {IsHoliday: False, Type: B} -> {Weekly_Sales: 5} (conf: 0.110, supp: 0.040, lift: 1.101, conv: 1.011)
# {CPI: 3, IsHoliday: False} -> {Weekly_Sales: 8} (conf: 0.110, supp: 0.010, lift: 1.101, conv: 1.011)
# {CPI: 5} -> {Weekly_Sales: 6} (conf: 0.110, supp: 0.011, lift: 1.101, conv: 1.011)
# {CPI: 9} -> {Weekly_Sales: 2} (conf: 0.110, supp: 0.011, lift: 1.101, conv: 1.011)
# {CPI: 8} -> {Weekly_Sales: 1} (conf: 0.110, supp: 0.011, lift: 1.100, conv: 1.011)
# {CPI: 7, IsHoliday: False} -> {Weekly_Sales: 1} (conf: 0.110, supp: 0.010, lift: 1.100, conv: 1.011)
# {CPI: 9, IsHoliday: False} -> {Weekly_Sales: 2} (conf: 0.110, supp: 0.010, lift: 1.100, conv: 1.011)
# {Unemployment: 8} -> {Weekly_Sales: 6} (conf: 0.110, supp: 0.011, lift: 1.099, conv: 1.011)
# {IsHoliday: False, Temperature: 8} -> {Weekly_Sales: 9} (conf: 0.110, supp: 0.011, lift: 1.099, conv: 1.011)
# {Type: B} -> {Weekly_Sales: 5} (conf: 0.110, supp: 0.043, lift: 1.098, conv: 1.011)
# {IsHoliday: False, Unemployment: 8} -> {Weekly_Sales: 6} (conf: 0.110, supp: 0.010, lift: 1.097, conv: 1.011)
# {CPI: 8, IsHoliday: False} -> {Weekly_Sales: 1} (conf: 0.110, supp: 0.010, lift: 1.097, conv: 1.011)
# {Unemployment: 1} -> {Weekly_Sales: 4} (conf: 0.110, supp: 0.011, lift: 1.095, conv: 1.011)
# {Fuel_Price: 0, IsHoliday: False} -> {Weekly_Sales: 1} (conf: 0.109, supp: 0.010, lift: 1.095, conv: 1.011)
# {Temperature: 8} -> {Weekly_Sales: 9} (conf: 0.109, supp: 0.011, lift: 1.094, conv: 1.011)
# {Fuel_Price: 0, IsHoliday: False} -> {Weekly_Sales: 2} (conf: 0.109, supp: 0.010, lift: 1.093, conv: 1.010)
# {CPI: 7} -> {Weekly_Sales: 1} (conf: 0.109, supp: 0.011, lift: 1.092, conv: 1.010)
# {Fuel_Price: 0} -> {Weekly_Sales: 1} (conf: 0.109, supp: 0.011, lift: 1.092, conv: 1.010)
# {IsHoliday: False, Size: 4} -> {Weekly_Sales: 6} (conf: 0.109, supp: 0.012, lift: 1.091, conv: 1.010)
# {IsHoliday: False, Size: 4, Type: B} -> {Weekly_Sales: 6} (conf: 0.109, supp: 0.012, lift: 1.091, conv: 1.010)
# {CPI: 5, IsHoliday: False} -> {Weekly_Sales: 4} (conf: 0.109, supp: 0.010, lift: 1.091, conv: 1.010)
# {IsHoliday: False, Type: B} -> {Weekly_Sales: 4} (conf: 0.109, supp: 0.039, lift: 1.090, conv: 1.010)
# {Size: 4} -> {Weekly_Sales: 6} (conf: 0.109, supp: 0.013, lift: 1.090, conv: 1.010)
# {Size: 4, Type: B} -> {Weekly_Sales: 6} (conf: 0.109, supp: 0.013, lift: 1.090, conv: 1.010)
# {Unemployment: 3} -> {Weekly_Sales: 8} (conf: 0.109, supp: 0.011, lift: 1.089, conv: 1.010)
# {Unemployment: 6} -> {Weekly_Sales: 9} (conf: 0.109, supp: 0.011, lift: 1.089, conv: 1.010)
# {Unemployment: 0} -> {Weekly_Sales: 9} (conf: 0.109, supp: 0.011, lift: 1.087, conv: 1.010)
# {CPI: 5, IsHoliday: False} -> {Weekly_Sales: 6} (conf: 0.109, supp: 0.010, lift: 1.087, conv: 1.010)
# {Fuel_Price: 0} -> {Weekly_Sales: 2} (conf: 0.109, supp: 0.011, lift: 1.086, conv: 1.010)
# {CPI: 3} -> {Weekly_Sales: 6} (conf: 0.109, supp: 0.011, lift: 1.085, conv: 1.010)
# {CPI: 3} -> {Weekly_Sales: 2} (conf: 0.109, supp: 0.011, lift: 1.085, conv: 1.010)
# {IsHoliday: False, Unemployment: 3} -> {Weekly_Sales: 8} (conf: 0.109, supp: 0.010, lift: 1.085, conv: 1.010)
# {Type: B} -> {Weekly_Sales: 4} (conf: 0.108, supp: 0.042, lift: 1.085, conv: 1.010)
# {IsHoliday: False, Unemployment: 0} -> {Weekly_Sales: 9} (conf: 0.108, supp: 0.010, lift: 1.084, conv: 1.009)
# {CPI: 4, IsHoliday: False} -> {Weekly_Sales: 6} (conf: 0.108, supp: 0.010, lift: 1.084, conv: 1.009)
# {Fuel_Price: 5} -> {Weekly_Sales: 2} (conf: 0.108, supp: 0.011, lift: 1.084, conv: 1.009)
# {Temperature: 2} -> {Weekly_Sales: 3} (conf: 0.108, supp: 0.011, lift: 1.083, conv: 1.009)
# {CPI: 4} -> {Weekly_Sales: 6} (conf: 0.108, supp: 0.011, lift: 1.083, conv: 1.009)
# {Size: 6} -> {Weekly_Sales: 4} (conf: 0.108, supp: 0.010, lift: 1.083, conv: 1.009)
# {Size: 6, Type: A} -> {Weekly_Sales: 4} (conf: 0.108, supp: 0.010, lift: 1.083, conv: 1.009)
# {CPI: 7} -> {Weekly_Sales: 9} (conf: 0.108, supp: 0.011, lift: 1.083, conv: 1.009)
# {Temperature: 8} -> {Weekly_Sales: 1} (conf: 0.108, supp: 0.011, lift: 1.082, conv: 1.009)
# {Fuel_Price: 5, IsHoliday: False} -> {Weekly_Sales: 2} (conf: 0.108, supp: 0.010, lift: 1.082, conv: 1.009)
# {CPI: 4, IsHoliday: False} -> {Weekly_Sales: 2} (conf: 0.108, supp: 0.010, lift: 1.082, conv: 1.009)
# {CPI: 5} -> {Weekly_Sales: 4} (conf: 0.108, supp: 0.011, lift: 1.081, conv: 1.009)
# {Fuel_Price: 1} -> {Weekly_Sales: 3} (conf: 0.108, supp: 0.011, lift: 1.079, conv: 1.009)
# {CPI: 4} -> {Weekly_Sales: 2} (conf: 0.108, supp: 0.011, lift: 1.079, conv: 1.009)
# {IsHoliday: False, Unemployment: 0} -> {Weekly_Sales: 5} (conf: 0.108, supp: 0.010, lift: 1.079, conv: 1.009)
# {Fuel_Price: 9} -> {Weekly_Sales: 7} (conf: 0.107, supp: 0.011, lift: 1.074, conv: 1.008)
# {Unemployment: 0} -> {Weekly_Sales: 5} (conf: 0.107, supp: 0.011, lift: 1.073, conv: 1.008)
# {IsHoliday: False, Temperature: 8} -> {Weekly_Sales: 1} (conf: 0.107, supp: 0.010, lift: 1.072, conv: 1.008)
# {Unemployment: 5} -> {Weekly_Sales: 8} (conf: 0.107, supp: 0.011, lift: 1.071, conv: 1.008)
# {Fuel_Price: 9, IsHoliday: False} -> {Weekly_Sales: 7} (conf: 0.107, supp: 0.010, lift: 1.071, conv: 1.008)
# {Fuel_Price: 9, IsHoliday: False} -> {Weekly_Sales: 0} (conf: 0.107, supp: 0.010, lift: 1.071, conv: 1.008)
# {Fuel_Price: 9} -> {Weekly_Sales: 0} (conf: 0.107, supp: 0.011, lift: 1.069, conv: 1.008)
# {Fuel_Price: 4} -> {Weekly_Sales: 2} (conf: 0.107, supp: 0.011, lift: 1.068, conv: 1.008)
# {Fuel_Price: 3} -> {Weekly_Sales: 0} (conf: 0.107, supp: 0.011, lift: 1.067, conv: 1.007)
# {CPI: 2} -> {Weekly_Sales: 6} (conf: 0.107, supp: 0.011, lift: 1.066, conv: 1.007)
# {CPI: 4, IsHoliday: False} -> {Weekly_Sales: 5} (conf: 0.107, supp: 0.010, lift: 1.066, conv: 1.007)
# {CPI: 2} -> {Weekly_Sales: 8} (conf: 0.107, supp: 0.011, lift: 1.065, conv: 1.007)
# {Size: 5} -> {Weekly_Sales: 4} (conf: 0.106, supp: 0.010, lift: 1.064, conv: 1.007)
# {Size: 5, Type: A} -> {Weekly_Sales: 4} (conf: 0.106, supp: 0.010, lift: 1.064, conv: 1.007)
# {Size: 5} -> {Weekly_Sales: 7} (conf: 0.106, supp: 0.010, lift: 1.064, conv: 1.007)
# {Size: 5, Type: A} -> {Weekly_Sales: 7} (conf: 0.106, supp: 0.010, lift: 1.064, conv: 1.007)
# {CPI: 2} -> {Weekly_Sales: 7} (conf: 0.106, supp: 0.011, lift: 1.064, conv: 1.007)
# {CPI: 4} -> {Weekly_Sales: 5} (conf: 0.106, supp: 0.011, lift: 1.064, conv: 1.007)
# {Unemployment: 4} -> {Weekly_Sales: 3} (conf: 0.106, supp: 0.011, lift: 1.063, conv: 1.007)
# {Unemployment: 2} -> {Weekly_Sales: 9} (conf: 0.106, supp: 0.011, lift: 1.063, conv: 1.007)
# {Fuel_Price: 2, IsHoliday: False} -> {Weekly_Sales: 9} (conf: 0.106, supp: 0.010, lift: 1.063, conv: 1.007)
# {Fuel_Price: 2} -> {Weekly_Sales: 8} (conf: 0.106, supp: 0.011, lift: 1.060, conv: 1.007)
# {Fuel_Price: 2, IsHoliday: False} -> {Weekly_Sales: 8} (conf: 0.106, supp: 0.010, lift: 1.059, conv: 1.007)
# {Type: B} -> {Weekly_Sales: 6} (conf: 0.106, supp: 0.041, lift: 1.059, conv: 1.007)
# {Unemployment: 5} -> {Weekly_Sales: 7} (conf: 0.106, supp: 0.011, lift: 1.058, conv: 1.007)
# {CPI: 8} -> {Weekly_Sales: 3} (conf: 0.106, supp: 0.011, lift: 1.058, conv: 1.007)
# {IsHoliday: False, Unemployment: 2} -> {Weekly_Sales: 9} (conf: 0.106, supp: 0.010, lift: 1.057, conv: 1.006)
# {Fuel_Price: 1} -> {Weekly_Sales: 6} (conf: 0.106, supp: 0.011, lift: 1.056, conv: 1.006)
# {IsHoliday: False, Type: B} -> {Weekly_Sales: 6} (conf: 0.106, supp: 0.038, lift: 1.056, conv: 1.006)
# {Fuel_Price: 2} -> {Weekly_Sales: 9} (conf: 0.106, supp: 0.011, lift: 1.055, conv: 1.006)
# {Temperature: 7} -> {Weekly_Sales: 9} (conf: 0.105, supp: 0.011, lift: 1.054, conv: 1.006)
# {IsHoliday: False, Temperature: 7} -> {Weekly_Sales: 4} (conf: 0.105, supp: 0.010, lift: 1.053, conv: 1.006)
# {Temperature: 1} -> {Weekly_Sales: 6} (conf: 0.105, supp: 0.011, lift: 1.053, conv: 1.006)
# {Temperature: 2} -> {Weekly_Sales: 6} (conf: 0.105, supp: 0.011, lift: 1.052, conv: 1.006)
# {Size: 7} -> {Weekly_Sales: 3} (conf: 0.105, supp: 0.010, lift: 1.051, conv: 1.006)
# {Size: 7, Type: A} -> {Weekly_Sales: 3} (conf: 0.105, supp: 0.010, lift: 1.051, conv: 1.006)
# {Unemployment: 9} -> {Weekly_Sales: 5} (conf: 0.105, supp: 0.010, lift: 1.051, conv: 1.006)
# {Fuel_Price: 9, IsHoliday: False} -> {Weekly_Sales: 5} (conf: 0.105, supp: 0.010, lift: 1.051, conv: 1.006)
# {IsHoliday: False, Temperature: 7} -> {Weekly_Sales: 9} (conf: 0.105, supp: 0.010, lift: 1.051, conv: 1.006)
# {Fuel_Price: 4} -> {Weekly_Sales: 1} (conf: 0.105, supp: 0.010, lift: 1.049, conv: 1.006)
# {Temperature: 7} -> {Weekly_Sales: 4} (conf: 0.105, supp: 0.010, lift: 1.049, conv: 1.006)
# {Unemployment: 6} -> {Weekly_Sales: 6} (conf: 0.105, supp: 0.010, lift: 1.049, conv: 1.005)
# {CPI: 3} -> {Weekly_Sales: 5} (conf: 0.105, supp: 0.011, lift: 1.049, conv: 1.005)
# {Unemployment: 8} -> {Weekly_Sales: 7} (conf: 0.105, supp: 0.010, lift: 1.048, conv: 1.005)
# {Fuel_Price: 9} -> {Weekly_Sales: 5} (conf: 0.105, supp: 0.010, lift: 1.048, conv: 1.005)
# {Unemployment: 4} -> {Weekly_Sales: 8} (conf: 0.105, supp: 0.010, lift: 1.047, conv: 1.005)
# {Unemployment: 7} -> {Weekly_Sales: 7} (conf: 0.105, supp: 0.011, lift: 1.047, conv: 1.005)
# {Fuel_Price: 1} -> {Weekly_Sales: 5} (conf: 0.105, supp: 0.010, lift: 1.047, conv: 1.005)
# {Fuel_Price: 7} -> {Weekly_Sales: 0} (conf: 0.105, supp: 0.010, lift: 1.046, conv: 1.005)
# {Temperature: 7} -> {Weekly_Sales: 7} (conf: 0.105, supp: 0.010, lift: 1.045, conv: 1.005)
# {Fuel_Price: 2, IsHoliday: False} -> {Weekly_Sales: 6} (conf: 0.104, supp: 0.010, lift: 1.045, conv: 1.005)
# {IsHoliday: False, Temperature: 7} -> {Weekly_Sales: 7} (conf: 0.104, supp: 0.010, lift: 1.045, conv: 1.005)
# {CPI: 8} -> {Weekly_Sales: 4} (conf: 0.104, supp: 0.010, lift: 1.044, conv: 1.005)
# {Unemployment: 7} -> {Weekly_Sales: 2} (conf: 0.104, supp: 0.011, lift: 1.044, conv: 1.005)
# {Fuel_Price: 8} -> {Weekly_Sales: 8} (conf: 0.104, supp: 0.011, lift: 1.044, conv: 1.005)
# {CPI: 7} -> {Weekly_Sales: 0} (conf: 0.104, supp: 0.010, lift: 1.044, conv: 1.005)
# {Fuel_Price: 8, IsHoliday: False} -> {Weekly_Sales: 8} (conf: 0.104, supp: 0.010, lift: 1.043, conv: 1.005)
# {Temperature: 5} -> {Weekly_Sales: 8} (conf: 0.104, supp: 0.010, lift: 1.043, conv: 1.005)
# {Fuel_Price: 2} -> {Weekly_Sales: 6} (conf: 0.104, supp: 0.011, lift: 1.043, conv: 1.005)
# {Temperature: 2} -> {Weekly_Sales: 2} (conf: 0.104, supp: 0.010, lift: 1.042, conv: 1.005)
# {Fuel_Price: 6, IsHoliday: False} -> {Weekly_Sales: 0} (conf: 0.104, supp: 0.010, lift: 1.042, conv: 1.005)
# {Temperature: 7} -> {Weekly_Sales: 8} (conf: 0.104, supp: 0.010, lift: 1.041, conv: 1.005)
# {CPI: 9} -> {Weekly_Sales: 0} (conf: 0.104, supp: 0.010, lift: 1.041, conv: 1.005)
# {CPI: 2} -> {Weekly_Sales: 4} (conf: 0.104, supp: 0.010, lift: 1.040, conv: 1.004)
# {IsHoliday: False, Temperature: 7} -> {Weekly_Sales: 8} (conf: 0.104, supp: 0.010, lift: 1.040, conv: 1.004)
# {Unemployment: 7} -> {Weekly_Sales: 9} (conf: 0.104, supp: 0.011, lift: 1.039, conv: 1.004)
# {Unemployment: 6} -> {Weekly_Sales: 0} (conf: 0.104, supp: 0.010, lift: 1.039, conv: 1.004)
# {Unemployment: 4} -> {Weekly_Sales: 9} (conf: 0.104, supp: 0.010, lift: 1.039, conv: 1.004)
# {Unemployment: 2} -> {Weekly_Sales: 3} (conf: 0.104, supp: 0.011, lift: 1.039, conv: 1.004)
# {CPI: 0} -> {Weekly_Sales: 8} (conf: 0.104, supp: 0.010, lift: 1.037, conv: 1.004)
# {IsHoliday: False, Temperature: 4} -> {Weekly_Sales: 5} (conf: 0.104, supp: 0.010, lift: 1.037, conv: 1.004)
# {Fuel_Price: 4} -> {Weekly_Sales: 9} (conf: 0.104, supp: 0.010, lift: 1.036, conv: 1.004)
# {Fuel_Price: 6} -> {Weekly_Sales: 0} (conf: 0.104, supp: 0.010, lift: 1.036, conv: 1.004)
# {CPI: 2} -> {Weekly_Sales: 5} (conf: 0.104, supp: 0.010, lift: 1.035, conv: 1.004)
# {CPI: 4} -> {Weekly_Sales: 3} (conf: 0.104, supp: 0.010, lift: 1.035, conv: 1.004)
# {Unemployment: 5} -> {Weekly_Sales: 6} (conf: 0.103, supp: 0.010, lift: 1.035, conv: 1.004)
# {CPI: 4} -> {Weekly_Sales: 4} (conf: 0.103, supp: 0.010, lift: 1.033, conv: 1.004)
# {Temperature: 4} -> {Weekly_Sales: 5} (conf: 0.103, supp: 0.010, lift: 1.033, conv: 1.004)
# {Temperature: 6} -> {Weekly_Sales: 8} (conf: 0.103, supp: 0.010, lift: 1.032, conv: 1.004)
# {Temperature: 0} -> {Weekly_Sales: 6} (conf: 0.103, supp: 0.010, lift: 1.032, conv: 1.004)
# {Fuel_Price: 8, IsHoliday: False} -> {Weekly_Sales: 7} (conf: 0.103, supp: 0.010, lift: 1.031, conv: 1.003)
# {Fuel_Price: 8} -> {Weekly_Sales: 7} (conf: 0.103, supp: 0.010, lift: 1.030, conv: 1.003)
# {Temperature: 6} -> {Weekly_Sales: 4} (conf: 0.103, supp: 0.010, lift: 1.030, conv: 1.003)
# {Temperature: 5} -> {Weekly_Sales: 5} (conf: 0.103, supp: 0.010, lift: 1.030, conv: 1.003)
# {Fuel_Price: 5} -> {Weekly_Sales: 3} (conf: 0.103, supp: 0.010, lift: 1.030, conv: 1.003)
# {Temperature: 2} -> {Weekly_Sales: 8} (conf: 0.103, supp: 0.010, lift: 1.030, conv: 1.003)
# {Unemployment: 3} -> {Weekly_Sales: 5} (conf: 0.103, supp: 0.010, lift: 1.029, conv: 1.003)
# {Fuel_Price: 5} -> {Weekly_Sales: 1} (conf: 0.103, supp: 0.010, lift: 1.029, conv: 1.003)
# {Temperature: 3} -> {Weekly_Sales: 6} (conf: 0.103, supp: 0.010, lift: 1.029, conv: 1.003)
# {Fuel_Price: 6} -> {Weekly_Sales: 2} (conf: 0.103, supp: 0.010, lift: 1.028, conv: 1.003)
# {CPI: 0} -> {Weekly_Sales: 5} (conf: 0.103, supp: 0.010, lift: 1.028, conv: 1.003)
# {Fuel_Price: 1} -> {Weekly_Sales: 4} (conf: 0.103, supp: 0.010, lift: 1.027, conv: 1.003)
# {Temperature: 1} -> {Weekly_Sales: 7} (conf: 0.103, supp: 0.010, lift: 1.027, conv: 1.003)
# {Fuel_Price: 5} -> {Weekly_Sales: 4} (conf: 0.103, supp: 0.010, lift: 1.026, conv: 1.003)
# {Unemployment: 3} -> {Weekly_Sales: 3} (conf: 0.103, supp: 0.010, lift: 1.026, conv: 1.003)
# {Unemployment: 2} -> {Weekly_Sales: 4} (conf: 0.103, supp: 0.010, lift: 1.026, conv: 1.003)
# {Temperature: 5} -> {Weekly_Sales: 4} (conf: 0.103, supp: 0.010, lift: 1.026, conv: 1.003)
# {Temperature: 4} -> {Weekly_Sales: 3} (conf: 0.103, supp: 0.010, lift: 1.026, conv: 1.003)
# {Fuel_Price: 8, IsHoliday: False} -> {Weekly_Sales: 4} (conf: 0.103, supp: 0.010, lift: 1.025, conv: 1.003)
# {Fuel_Price: 9} -> {Weekly_Sales: 6} (conf: 0.102, supp: 0.010, lift: 1.025, conv: 1.003)
# {IsHoliday: False, Type: A} -> {Weekly_Sales: 4} (conf: 0.102, supp: 0.049, lift: 1.024, conv: 1.003)
# {Unemployment: 5} -> {Weekly_Sales: 3} (conf: 0.102, supp: 0.010, lift: 1.024, conv: 1.003)
# {Fuel_Price: 1} -> {Weekly_Sales: 8} (conf: 0.102, supp: 0.010, lift: 1.023, conv: 1.003)
# {Fuel_Price: 8} -> {Weekly_Sales: 4} (conf: 0.102, supp: 0.010, lift: 1.023, conv: 1.003)
# {Unemployment: 5} -> {Weekly_Sales: 4} (conf: 0.102, supp: 0.010, lift: 1.023, conv: 1.003)
# {Fuel_Price: 8, IsHoliday: False} -> {Weekly_Sales: 0} (conf: 0.102, supp: 0.010, lift: 1.023, conv: 1.003)
# {Fuel_Price: 0} -> {Weekly_Sales: 6} (conf: 0.102, supp: 0.010, lift: 1.023, conv: 1.003)
# {Temperature: 3} -> {Weekly_Sales: 9} (conf: 0.102, supp: 0.010, lift: 1.022, conv: 1.002)
# {Temperature: 5} -> {Weekly_Sales: 7} (conf: 0.102, supp: 0.010, lift: 1.021, conv: 1.002)
# {CPI: 8} -> {Weekly_Sales: 5} (conf: 0.102, supp: 0.010, lift: 1.021, conv: 1.002)
# {CPI: 6} -> {Weekly_Sales: 9} (conf: 0.102, supp: 0.010, lift: 1.021, conv: 1.002)
# {Fuel_Price: 2} -> {Weekly_Sales: 7} (conf: 0.102, supp: 0.010, lift: 1.021, conv: 1.002)
# {Temperature: 8} -> {Weekly_Sales: 8} (conf: 0.102, supp: 0.010, lift: 1.021, conv: 1.002)
# {Fuel_Price: 9} -> {Weekly_Sales: 8} (conf: 0.102, supp: 0.010, lift: 1.021, conv: 1.002)
# {Unemployment: 4} -> {Weekly_Sales: 4} (conf: 0.102, supp: 0.010, lift: 1.020, conv: 1.002)
# {Unemployment: 2} -> {Weekly_Sales: 5} (conf: 0.102, supp: 0.010, lift: 1.020, conv: 1.002)
# {Temperature: 4} -> {Weekly_Sales: 2} (conf: 0.102, supp: 0.010, lift: 1.020, conv: 1.002)
# {CPI: 9} -> {Weekly_Sales: 4} (conf: 0.102, supp: 0.010, lift: 1.019, conv: 1.002)
# {Fuel_Price: 2} -> {Weekly_Sales: 5} (conf: 0.102, supp: 0.010, lift: 1.019, conv: 1.002)
# {Fuel_Price: 8} -> {Weekly_Sales: 0} (conf: 0.102, supp: 0.010, lift: 1.019, conv: 1.002)
# {Temperature: 6} -> {Weekly_Sales: 6} (conf: 0.102, supp: 0.010, lift: 1.018, conv: 1.002)
# {Temperature: 2} -> {Weekly_Sales: 7} (conf: 0.102, supp: 0.010, lift: 1.017, conv: 1.002)
# {Type: A} -> {Weekly_Sales: 4} (conf: 0.102, supp: 0.052, lift: 1.017, conv: 1.002)
# {Fuel_Price: 2} -> {Weekly_Sales: 3} (conf: 0.102, supp: 0.010, lift: 1.017, conv: 1.002)
# {CPI: 1} -> {Weekly_Sales: 8} (conf: 0.102, supp: 0.010, lift: 1.017, conv: 1.002)
# {Fuel_Price: 8} -> {Weekly_Sales: 5} (conf: 0.102, supp: 0.010, lift: 1.016, conv: 1.002)
# {Fuel_Price: 0} -> {Weekly_Sales: 4} (conf: 0.102, supp: 0.010, lift: 1.016, conv: 1.002)
# {Fuel_Price: 6} -> {Weekly_Sales: 4} (conf: 0.102, supp: 0.010, lift: 1.015, conv: 1.002)
# {Unemployment: 4} -> {Weekly_Sales: 5} (conf: 0.101, supp: 0.010, lift: 1.015, conv: 1.002)
# {Fuel_Price: 3} -> {Weekly_Sales: 1} (conf: 0.101, supp: 0.010, lift: 1.014, conv: 1.002)
# {Fuel_Price: 4} -> {Weekly_Sales: 0} (conf: 0.101, supp: 0.010, lift: 1.014, conv: 1.002)
# {IsHoliday: False, Size: 4} -> {Weekly_Sales: 4} (conf: 0.101, supp: 0.011, lift: 1.014, conv: 1.002)
# {IsHoliday: False, Size: 4, Type: B} -> {Weekly_Sales: 4} (conf: 0.101, supp: 0.011, lift: 1.014, conv: 1.002)
# {Fuel_Price: 7} -> {Weekly_Sales: 4} (conf: 0.101, supp: 0.010, lift: 1.014, conv: 1.002)
# {Size: 4} -> {Weekly_Sales: 4} (conf: 0.101, supp: 0.012, lift: 1.013, conv: 1.001)
# {Size: 4, Type: B} -> {Weekly_Sales: 4} (conf: 0.101, supp: 0.012, lift: 1.013, conv: 1.001)
# {Temperature: 3} -> {Weekly_Sales: 1} (conf: 0.101, supp: 0.010, lift: 1.012, conv: 1.001)
# {CPI: 7} -> {Weekly_Sales: 2} (conf: 0.101, supp: 0.010, lift: 1.011, conv: 1.001)
# {CPI: 3} -> {Weekly_Sales: 4} (conf: 0.101, supp: 0.010, lift: 1.011, conv: 1.001)
# {Temperature: 3} -> {Weekly_Sales: 7} (conf: 0.101, supp: 0.010, lift: 1.011, conv: 1.001)
# {Unemployment: 8} -> {Weekly_Sales: 1} (conf: 0.101, supp: 0.010, lift: 1.010, conv: 1.001)
# {Temperature: 1} -> {Weekly_Sales: 9} (conf: 0.101, supp: 0.010, lift: 1.010, conv: 1.001)
# {Temperature: 7} -> {Weekly_Sales: 0} (conf: 0.101, supp: 0.010, lift: 1.010, conv: 1.001)
# {Fuel_Price: 3} -> {Weekly_Sales: 8} (conf: 0.101, supp: 0.010, lift: 1.009, conv: 1.001)
# {Unemployment: 2} -> {Weekly_Sales: 2} (conf: 0.101, supp: 0.010, lift: 1.009, conv: 1.001)
# {Temperature: 3} -> {Weekly_Sales: 8} (conf: 0.101, supp: 0.010, lift: 1.009, conv: 1.001)
# {Fuel_Price: 6} -> {Weekly_Sales: 1} (conf: 0.101, supp: 0.010, lift: 1.008, conv: 1.001)
# {Temperature: 1} -> {Weekly_Sales: 4} (conf: 0.101, supp: 0.010, lift: 1.008, conv: 1.001)
# {Unemployment: 0} -> {Weekly_Sales: 3} (conf: 0.101, supp: 0.010, lift: 1.007, conv: 1.001)
# {Temperature: 6} -> {Weekly_Sales: 9} (conf: 0.101, supp: 0.010, lift: 1.007, conv: 1.001)
# {Temperature: 4} -> {Weekly_Sales: 7} (conf: 0.101, supp: 0.010, lift: 1.007, conv: 1.001)
# {Type: A} -> {Weekly_Sales: 6} (conf: 0.101, supp: 0.051, lift: 1.006, conv: 1.001)
# {IsHoliday: False} -> {Weekly_Sales: 4} (conf: 0.101, supp: 0.093, lift: 1.005, conv: 1.001)
# {Fuel_Price: 0} -> {Weekly_Sales: 3} (conf: 0.101, supp: 0.010, lift: 1.005, conv: 1.001)
# {Fuel_Price: 3} -> {Weekly_Sales: 6} (conf: 0.100, supp: 0.010, lift: 1.005, conv: 1.001)
# {Fuel_Price: 1} -> {Weekly_Sales: 2} (conf: 0.100, supp: 0.010, lift: 1.005, conv: 1.001)
# {IsHoliday: False} -> {Weekly_Sales: 5} (conf: 0.100, supp: 0.093, lift: 1.005, conv: 1.001)
# {IsHoliday: False, Type: A} -> {Weekly_Sales: 6} (conf: 0.100, supp: 0.048, lift: 1.004, conv: 1.000)
# {Unemployment: 2} -> {Weekly_Sales: 1} (conf: 0.100, supp: 0.010, lift: 1.004, conv: 1.000)
# {Unemployment: 7} -> {Weekly_Sales: 5} (conf: 0.100, supp: 0.010, lift: 1.003, conv: 1.000)
# {Temperature: 6} -> {Weekly_Sales: 3} (conf: 0.100, supp: 0.010, lift: 1.003, conv: 1.000)
# {Temperature: 0} -> {Weekly_Sales: 7} (conf: 0.100, supp: 0.010, lift: 1.003, conv: 1.000)
# {Fuel_Price: 8} -> {Weekly_Sales: 3} (conf: 0.100, supp: 0.010, lift: 1.002, conv: 1.000)
# {Temperature: 2} -> {Weekly_Sales: 9} (conf: 0.100, supp: 0.010, lift: 1.002, conv: 1.000)
# {Temperature: 8} -> {Weekly_Sales: 5} (conf: 0.100, supp: 0.010, lift: 1.002, conv: 1.000)
# {IsHoliday: False} -> {Weekly_Sales: 0} (conf: 0.100, supp: 0.093, lift: 1.002, conv: 1.000)
# {CPI: 9} -> {Weekly_Sales: 3} (conf: 0.100, supp: 0.010, lift: 1.001, conv: 1.000)
# {IsHoliday: False} -> {Weekly_Sales: 3} (conf: 0.100, supp: 0.093, lift: 1.001, conv: 1.000)
# {Temperature: 0} -> {Weekly_Sales: 5} (conf: 0.100, supp: 0.010, lift: 1.001, conv: 1.000)
# {Temperature: 4} -> {Weekly_Sales: 4} (conf: 0.100, supp: 0.010, lift: 1.001, conv: 1.000)
# {Temperature: 0} -> {Weekly_Sales: 4} (conf: 0.100, supp: 0.010, lift: 1.001, conv: 1.000)
# {Temperature: 4} -> {Weekly_Sales: 6} (conf: 0.100, supp: 0.010, lift: 1.001, conv: 1.000)
# {Temperature: 4} -> {Weekly_Sales: 0} (conf: 0.100, supp: 0.010, lift: 1.001, conv: 1.000)

# %%
rules_rhs = filter(lambda rule: len(rule.lhs) == 1 and len(rule.rhs) == 1, rules)
for rule in sorted(rules_rhs, key=lambda rule: rule.lift):
  print(rule)
# Out:
# {MarkDown2 nan} -> {store type A} (conf: 0.359, supp: 0.103, lift: 0.734, conv: 0.797)
# {Fuel_Price 3.53} -> {MarkDown3 41.73} (conf: 0.635, supp: 0.107, lift: 0.917, conv: 0.842)
# {store type A} -> {MarkDown3 41.73} (conf: 0.639, supp: 0.312, lift: 0.923, conv: 0.852)
# {MarkDown3 41.73} -> {store type A} (conf: 0.451, supp: 0.312, lift: 0.923, conv: 0.931)
# {store size 210384.65} -> {MarkDown3 41.73} (conf: 0.651, supp: 0.159, lift: 0.940, conv: 0.880)
# {Temperature 49.13} -> {MarkDown3 41.73} (conf: 0.656, supp: 0.106, lift: 0.947, conv: 0.894)
# {Temperature 49.13} -> {IsHoliday False} (conf: 0.879, supp: 0.142, lift: 0.954, conv: 0.648)
# {Unemployment 7.93} -> {MarkDown3 41.73} (conf: 0.663, supp: 0.126, lift: 0.957, conv: 0.912)
# {Unemployment 7.03} -> {MarkDown3 41.73} (conf: 0.664, supp: 0.177, lift: 0.960, conv: 0.917)
# {MarkDown2 -3.8} -> {MarkDown3 41.73} (conf: 0.670, supp: 0.133, lift: 0.968, conv: 0.933)
# {store type A} -> {CPI 134.69} (conf: 0.409, supp: 0.200, lift: 0.969, conv: 0.978)
# {CPI 134.69} -> {store type A} (conf: 0.474, supp: 0.200, lift: 0.969, conv: 0.971)
# {weekly sales 388410.7} -> {CPI 134.69} (conf: 0.410, supp: 0.101, lift: 0.970, conv: 0.979)
# {store type B} -> {CPI 134.69} (conf: 0.412, supp: 0.156, lift: 0.975, conv: 0.982)
# {CPI 134.69} -> {store type B} (conf: 0.368, supp: 0.156, lift: 0.975, conv: 0.985)
# {department number 72} -> {IsHoliday False} (conf: 0.899, supp: 0.105, lift: 0.976, conv: 0.779)
# {store size 44112.35} -> {MarkDown3 41.73} (conf: 0.682, supp: 0.152, lift: 0.986, conv: 0.968)
# {Unemployment 7.93} -> {IsHoliday False} (conf: 0.908, supp: 0.173, lift: 0.986, conv: 0.855)
# {weekly sales 388410.7} -> {MarkDown3 41.73} (conf: 0.683, supp: 0.168, lift: 0.986, conv: 0.969)
# {MarkDown2 -3.8} -> {IsHoliday False} (conf: 0.910, supp: 0.180, lift: 0.987, conv: 0.870)
# {weekly sales 1426719.63} -> {MarkDown3 41.73} (conf: 0.684, supp: 0.120, lift: 0.988, conv: 0.974)
# {Fuel_Price 3.68} -> {IsHoliday False} (conf: 0.911, supp: 0.197, lift: 0.989, conv: 0.886)
# {Unemployment 8.84} -> {IsHoliday False} (conf: 0.915, supp: 0.122, lift: 0.993, conv: 0.920)
# {CPI 193.14} -> {IsHoliday False} (conf: 0.920, supp: 0.100, lift: 0.998, conv: 0.980)
# {MarkDown3 41.73} -> {CPI 134.69} (conf: 0.422, supp: 0.292, lift: 0.999, conv: 0.999)
# {CPI 134.69} -> {MarkDown3 41.73} (conf: 0.691, supp: 0.292, lift: 0.999, conv: 0.997)
# {Temperature 86.18} -> {IsHoliday False} (conf: 0.920, supp: 0.101, lift: 0.999, conv: 0.984)
# {store size 154960.55} -> {IsHoliday False} (conf: 0.922, supp: 0.102, lift: 1.000, conv: 1.000)
# {store type A} -> {IsHoliday False} (conf: 0.922, supp: 0.451, lift: 1.000, conv: 1.000)
# {IsHoliday False} -> {store type A} (conf: 0.489, supp: 0.451, lift: 1.000, conv: 1.000)
# {store size 210384.65} -> {IsHoliday False} (conf: 0.922, supp: 0.225, lift: 1.000, conv: 1.000)
# {store size 44112.35} -> {IsHoliday False} (conf: 0.922, supp: 0.205, lift: 1.000, conv: 1.000)
# {store type B} -> {IsHoliday False} (conf: 0.922, supp: 0.348, lift: 1.000, conv: 1.000)
# {IsHoliday False} -> {store type B} (conf: 0.378, supp: 0.348, lift: 1.000, conv: 1.000)
# {IsHoliday False} -> {CPI 134.69} (conf: 0.422, supp: 0.389, lift: 1.000, conv: 1.000)
# {CPI 134.69} -> {IsHoliday False} (conf: 0.922, supp: 0.389, lift: 1.000, conv: 1.000)
# {store size 118011.15} -> {IsHoliday False} (conf: 0.922, supp: 0.164, lift: 1.000, conv: 1.000)
# {store type C} -> {IsHoliday False} (conf: 0.922, supp: 0.123, lift: 1.000, conv: 1.000)
# {weekly sales 1080616.65} -> {IsHoliday False} (conf: 0.922, supp: 0.181, lift: 1.001, conv: 1.008)
# {Unemployment 6.13} -> {IsHoliday False} (conf: 0.923, supp: 0.162, lift: 1.002, conv: 1.020)
# {IsHoliday False} -> {CPI 222.36} (conf: 0.306, supp: 0.282, lift: 1.003, conv: 1.001)
# {CPI 222.36} -> {IsHoliday False} (conf: 0.924, supp: 0.282, lift: 1.003, conv: 1.037)
# {Unemployment 7.03} -> {IsHoliday False} (conf: 0.928, supp: 0.247, lift: 1.007, conv: 1.089)
# {weekly sales 388410.7} -> {IsHoliday False} (conf: 0.929, supp: 0.228, lift: 1.008, conv: 1.106)
# {weekly sales 1426719.63} -> {IsHoliday False} (conf: 0.930, supp: 0.163, lift: 1.010, conv: 1.126)
# {weekly sales 734513.68} -> {IsHoliday False} (conf: 0.931, supp: 0.183, lift: 1.010, conv: 1.139)
# {department number 71} -> {IsHoliday False} (conf: 0.934, supp: 0.147, lift: 1.013, conv: 1.180)
# {MarkDown3 41.73} -> {CPI 222.36} (conf: 0.310, supp: 0.214, lift: 1.014, conv: 1.006)
# {CPI 222.36} -> {MarkDown3 41.73} (conf: 0.702, supp: 0.214, lift: 1.014, conv: 1.032)
# {weekly sales 1080616.65} -> {MarkDown3 41.73} (conf: 0.702, supp: 0.138, lift: 1.014, conv: 1.033)
# {MarkDown2 100.99} -> {IsHoliday False} (conf: 0.939, supp: 0.127, lift: 1.019, conv: 1.284)
# {MarkDown4 nan} -> {IsHoliday False} (conf: 0.939, supp: 0.135, lift: 1.019, conv: 1.294)
# {Temperature 58.4} -> {IsHoliday False} (conf: 0.943, supp: 0.153, lift: 1.024, conv: 1.386)
# {department number 71} -> {MarkDown3 41.73} (conf: 0.709, supp: 0.112, lift: 1.024, conv: 1.058)
# {MarkDown2 nan} -> {CPI 134.69} (conf: 0.433, supp: 0.124, lift: 1.026, conv: 1.019)
# {MarkDown3 41.73} -> {IsHoliday False} (conf: 0.947, supp: 0.656, lift: 1.028, conv: 1.484)
# {IsHoliday False} -> {MarkDown3 41.73} (conf: 0.712, supp: 0.656, lift: 1.028, conv: 1.067)
# {Fuel_Price 3.53} -> {IsHoliday False} (conf: 0.951, supp: 0.160, lift: 1.032, conv: 1.593)
# {department number 70} -> {IsHoliday False} (conf: 0.951, supp: 0.135, lift: 1.032, conv: 1.598)
# {department number 69} -> {IsHoliday False} (conf: 0.955, supp: 0.103, lift: 1.037, conv: 1.761)
# {MarkDown3 nan} -> {IsHoliday False} (conf: 0.956, supp: 0.104, lift: 1.037, conv: 1.775)
# {Unemployment 6.13} -> {MarkDown3 41.73} (conf: 0.720, supp: 0.126, lift: 1.039, conv: 1.097)
# {store size 118011.15} -> {MarkDown3 41.73} (conf: 0.721, supp: 0.128, lift: 1.041, conv: 1.101)
# {Fuel_Price 3.68} -> {store type A} (conf: 0.511, supp: 0.111, lift: 1.045, conv: 1.045)
# {MarkDown2 nan} -> {IsHoliday False} (conf: 0.965, supp: 0.277, lift: 1.047, conv: 2.244)
# {IsHoliday False} -> {MarkDown2 nan} (conf: 0.300, supp: 0.277, lift: 1.047, conv: 1.019)
# {MarkDown3 41.73} -> {MarkDown2 nan} (conf: 0.301, supp: 0.208, lift: 1.049, conv: 1.020)
# {MarkDown2 nan} -> {MarkDown3 41.73} (conf: 0.726, supp: 0.208, lift: 1.049, conv: 1.125)
# {Temperature 67.66} -> {IsHoliday False} (conf: 0.968, supp: 0.173, lift: 1.051, conv: 2.480)
# {Temperature 76.92} -> {IsHoliday False} (conf: 0.970, supp: 0.167, lift: 1.052, conv: 2.588)
# {store type B} -> {MarkDown3 41.73} (conf: 0.736, supp: 0.278, lift: 1.063, conv: 1.165)
# {MarkDown3 41.73} -> {store type B} (conf: 0.402, supp: 0.278, lift: 1.063, conv: 1.040)
# {Fuel_Price 3.82} -> {IsHoliday False} (conf: 0.982, supp: 0.167, lift: 1.066, conv: 4.370)
# {Fuel_Price 3.68} -> {MarkDown3 41.73} (conf: 0.748, supp: 0.162, lift: 1.081, conv: 1.223)
# {Temperature 76.92} -> {MarkDown3 41.73} (conf: 0.750, supp: 0.129, lift: 1.083, conv: 1.231)
# {Temperature 58.4} -> {MarkDown3 41.73} (conf: 0.760, supp: 0.123, lift: 1.098, conv: 1.282)
# {store type C} -> {MarkDown3 41.73} (conf: 0.765, supp: 0.102, lift: 1.104, conv: 1.307)
# {Fuel_Price 3.82} -> {MarkDown3 41.73} (conf: 0.772, supp: 0.131, lift: 1.115, conv: 1.348)
# {weekly sales 388410.7} -> {store type B} (conf: 0.426, supp: 0.105, lift: 1.126, conv: 1.083)
# {Temperature 67.66} -> {MarkDown3 41.73} (conf: 0.786, supp: 0.141, lift: 1.135, conv: 1.437)
# {weekly sales 734513.68} -> {MarkDown3 41.73} (conf: 0.804, supp: 0.158, lift: 1.162, conv: 1.573)
# {store type A} -> {CPI 222.36} (conf: 0.357, supp: 0.174, lift: 1.167, conv: 1.079)
# {CPI 222.36} -> {store type A} (conf: 0.571, supp: 0.174, lift: 1.167, conv: 1.190)
# {store type A} -> {Unemployment 7.03} (conf: 0.313, supp: 0.153, lift: 1.175, conv: 1.068)
# {Unemployment 7.03} -> {store type A} (conf: 0.574, supp: 0.153, lift: 1.175, conv: 1.201)
# {weekly sales 1080616.65} -> {store type A} (conf: 0.580, supp: 0.114, lift: 1.186, conv: 1.217)
# {store size 118011.15} -> {CPI 134.69} (conf: 0.625, supp: 0.111, lift: 1.480, conv: 1.541)
# {weekly sales 388410.7} -> {CPI 222.36} (conf: 0.477, supp: 0.117, lift: 1.561, conv: 1.328)
# {CPI 222.36} -> {weekly sales 388410.7} (conf: 0.384, supp: 0.117, lift: 1.561, conv: 1.224)
# {weekly sales 1080616.65} -> {CPI 134.69} (conf: 0.660, supp: 0.129, lift: 1.563, conv: 1.699)
# {CPI 134.69} -> {weekly sales 1080616.65} (conf: 0.307, supp: 0.129, lift: 1.563, conv: 1.159)
# {store size 44112.35} -> {CPI 222.36} (conf: 0.484, supp: 0.108, lift: 1.586, conv: 1.347)
# {CPI 222.36} -> {store size 44112.35} (conf: 0.352, supp: 0.108, lift: 1.586, conv: 1.201)
# {department number 71} -> {store type A} (conf: 0.823, supp: 0.129, lift: 1.683, conv: 2.883)
# {weekly sales 388410.7} -> {MarkDown2 nan} (conf: 0.491, supp: 0.121, lift: 1.713, conv: 1.402)
# {MarkDown2 nan} -> {weekly sales 388410.7} (conf: 0.421, supp: 0.121, lift: 1.713, conv: 1.303)
# {weekly sales 1426719.63} -> {store type A} (conf: 0.871, supp: 0.153, lift: 1.781, conv: 3.951)
# {store type A} -> {weekly sales 1426719.63} (conf: 0.312, supp: 0.153, lift: 1.781, conv: 1.199)
# {department number 72} -> {store type A} (conf: 0.907, supp: 0.106, lift: 1.855, conv: 5.479)
# {weekly sales 734513.68} -> {store type B} (conf: 0.720, supp: 0.141, lift: 1.906, conv: 2.222)
# {store type B} -> {weekly sales 734513.68} (conf: 0.374, supp: 0.141, lift: 1.906, conv: 1.284)
# {Unemployment 7.03} -> {CPI 222.36} (conf: 0.589, supp: 0.157, lift: 1.929, conv: 1.691)
# {CPI 222.36} -> {Unemployment 7.03} (conf: 0.514, supp: 0.157, lift: 1.929, conv: 1.508)
# {store size 44112.35} -> {MarkDown2 nan} (conf: 0.578, supp: 0.129, lift: 2.017, conv: 1.692)
# {MarkDown2 nan} -> {store size 44112.35} (conf: 0.448, supp: 0.129, lift: 2.017, conv: 1.410)
# {store size 154960.55} -> {store type A} (conf: 1.000, supp: 0.111, lift: 2.045, conv: 511111111.111)
# {store type A} -> {store size 210384.65} (conf: 0.500, supp: 0.244, lift: 2.045, conv: 1.511)
# {store size 210384.65} -> {store type A} (conf: 1.000, supp: 0.244, lift: 2.045, conv: 511111111.111)
# {weekly sales 1426719.63} -> {store size 210384.65} (conf: 0.592, supp: 0.104, lift: 2.422, conv: 1.852)
# {store size 210384.65} -> {weekly sales 1426719.63} (conf: 0.424, supp: 0.104, lift: 2.422, conv: 1.433)
# {store type B} -> {store size 118011.15} (conf: 0.471, supp: 0.178, lift: 2.647, conv: 1.553)
# {store size 118011.15} -> {store type B} (conf: 1.000, supp: 0.178, lift: 2.647, conv: 622222222.222)
# {weekly sales 388410.7} -> {MarkDown4 nan} (conf: 0.445, supp: 0.109, lift: 3.095, conv: 1.543)
# {MarkDown4 nan} -> {weekly sales 388410.7} (conf: 0.761, supp: 0.109, lift: 3.095, conv: 3.151)
# {weekly sales 388410.7} -> {store size 44112.35} (conf: 0.755, supp: 0.186, lift: 3.399, conv: 3.179)
# {store size 44112.35} -> {weekly sales 388410.7} (conf: 0.835, supp: 0.186, lift: 3.399, conv: 4.579)
# {store size 44112.35} -> {MarkDown4 nan} (conf: 0.633, supp: 0.141, lift: 4.405, conv: 2.335)
# {MarkDown4 nan} -> {store size 44112.35} (conf: 0.979, supp: 0.141, lift: 4.405, conv: 36.667)
# {store type C} -> {store size 44112.35} (conf: 1.000, supp: 0.133, lift: 4.500, conv: 777777777.778)
# {store size 44112.35} -> {store type C} (conf: 0.600, supp: 0.133, lift: 4.500, conv: 2.167)
# {store type C} -> {MarkDown4 nan} (conf: 0.768, supp: 0.102, lift: 5.341, conv: 3.690)
# {MarkDown4 nan} -> {store type C} (conf: 0.712, supp: 0.102, lift: 5.341, conv: 3.011)

# %%
rules_rhs = filter(lambda rule: len(rule.lhs) == 1 and len(rule.rhs) == 1, rules)
for rule in sorted(rules_rhs, key=lambda rule: rule.lift):
  print(rule)

# %%
rules_rhs = filter(lambda rule: len(rule.rhs) == 1 and rule.rhs[0].find('sale') != -1, rules)
for rule in sorted(rules_rhs, key=lambda rule: rule.lift, reverse=True):
  print(rule)
# Out:
# {CPI 222.36, store size 44112.35} -> {weekly sales 388410.7} (conf: 0.992, supp: 0.107, lift: 4.036, conv: 93.150)
# {store size 44112.35} -> {weekly sales 388410.7} (conf: 0.835, supp: 0.186, lift: 3.399, conv: 4.579)
# {IsHoliday False, store size 44112.35} -> {weekly sales 388410.7} (conf: 0.834, supp: 0.171, lift: 3.394, conv: 4.545)
# {MarkDown2 nan, store size 44112.35} -> {weekly sales 388410.7} (conf: 0.807, supp: 0.104, lift: 3.283, conv: 3.904)
# {IsHoliday False, MarkDown3 41.73, store size 44112.35} -> {weekly sales 388410.7} (conf: 0.791, supp: 0.112, lift: 3.218, conv: 3.605)
# {MarkDown3 41.73, store size 44112.35} -> {weekly sales 388410.7} (conf: 0.790, supp: 0.120, lift: 3.216, conv: 3.596)
# {MarkDown4 nan, store size 44112.35} -> {weekly sales 388410.7} (conf: 0.771, supp: 0.108, lift: 3.137, conv: 3.292)
# {IsHoliday False, MarkDown4 nan, store size 44112.35} -> {weekly sales 388410.7} (conf: 0.770, supp: 0.102, lift: 3.132, conv: 3.276)
# {IsHoliday False, MarkDown4 nan} -> {weekly sales 388410.7} (conf: 0.761, supp: 0.103, lift: 3.098, conv: 3.160)
# {MarkDown4 nan} -> {weekly sales 388410.7} (conf: 0.761, supp: 0.109, lift: 3.095, conv: 3.151)
# {store size 210384.65} -> {weekly sales 1426719.63} (conf: 0.424, supp: 0.104, lift: 2.422, conv: 1.433)
# {store size 210384.65, store type A} -> {weekly sales 1426719.63} (conf: 0.424, supp: 0.104, lift: 2.422, conv: 1.433)
# {IsHoliday False, MarkDown3 41.73, store type B} -> {weekly sales 734513.68} (conf: 0.400, supp: 0.104, lift: 2.042, conv: 1.341)
# {MarkDown3 41.73, store type B} -> {weekly sales 734513.68} (conf: 0.400, supp: 0.111, lift: 2.038, conv: 1.339)
# {IsHoliday False, MarkDown3 41.73, store type A} -> {weekly sales 1426719.63} (conf: 0.345, supp: 0.103, lift: 1.969, conv: 1.259)
# {MarkDown3 41.73, store type A} -> {weekly sales 1426719.63} (conf: 0.342, supp: 0.107, lift: 1.951, conv: 1.253)
# {IsHoliday False, store type B} -> {weekly sales 734513.68} (conf: 0.375, supp: 0.131, lift: 1.915, conv: 1.287)
# {store type B} -> {weekly sales 734513.68} (conf: 0.374, supp: 0.141, lift: 1.906, conv: 1.284)
# {IsHoliday False, store type A} -> {weekly sales 1426719.63} (conf: 0.316, supp: 0.142, lift: 1.805, conv: 1.206)
# {store type A} -> {weekly sales 1426719.63} (conf: 0.312, supp: 0.153, lift: 1.781, conv: 1.199)
# {MarkDown2 nan} -> {weekly sales 388410.7} (conf: 0.421, supp: 0.121, lift: 1.713, conv: 1.303)
# {IsHoliday False, MarkDown2 nan} -> {weekly sales 388410.7} (conf: 0.419, supp: 0.116, lift: 1.705, conv: 1.298)
# {CPI 134.69, IsHoliday False} -> {weekly sales 1080616.65} (conf: 0.310, supp: 0.121, lift: 1.582, conv: 1.165)
# {CPI 222.36, IsHoliday False} -> {weekly sales 388410.7} (conf: 0.386, supp: 0.109, lift: 1.570, conv: 1.228)
# {CPI 134.69} -> {weekly sales 1080616.65} (conf: 0.307, supp: 0.129, lift: 1.563, conv: 1.159)
# {CPI 222.36} -> {weekly sales 388410.7} (conf: 0.384, supp: 0.117, lift: 1.561, conv: 1.224)
